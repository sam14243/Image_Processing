# %%
import pandas as pd
import cv2
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# !pip install opencv-python

# %%
img = cv2.imread("cat.png")

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (638, 640, 3)

# %%
# ?cv2.resize

# %% [markdown]
# ## Image Resizing

# %%
img2 = cv2.resize(img, (1920, 1080), interpolation=cv2.INTER_NEAREST)
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)
cv2.imwrite('PPinternearest.png', img2)

img2 = cv2.resize(img, (1920, 1080), interpolation=cv2.INTER_CUBIC)
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)
cv2.imwrite('PPintercubic.png', img2)

img2 = cv2.resize(img, (1920, 1080), interpolation=cv2.INTER_LINEAR)
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)
cv2.imwrite('PPinterlinear.png', img2)

img2 = cv2.resize(img, (1920, 1080), interpolation=cv2.INTER_LANCZOS4)
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)
cv2.imwrite('PPinterlancos4.png', img2)

img2 = cv2.resize(img, (1920, 1080), interpolation=cv2.INTER_AREA)
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)
cv2.imwrite('PPinterarea.png', img2)
# Out:
# True

# %%
quat = cv2.resize(img, (159, 160))
plt.imshow(quat)

# %%
# LOSELESS AND LOSSY CONVERSION
# Interpolation wrt to compression

# %%
imgs = []
imgs.append(img)

# %%
new_height, new_width = 89, 90

# %% [markdown]
# #### Nearest Algorithm

# %%
img1 = cv2.resize(img, dsize=(new_height, new_width), 
      interpolation=cv2.INTER_NEAREST)
imgs.append(img1)
plt.imshow(img1)

# %% [markdown]
# #### Bilinear

# %%
img2 = cv2.resize(img, dsize=(new_height, new_width), 
      interpolation=cv2.INTER_LINEAR)
imgs.append(img2)
plt.imshow(img2)

# %% [markdown]
# #### Bicubic

# %%
img3 = cv2.resize(img, dsize=(new_height, new_width), 
      interpolation=cv2.INTER_CUBIC)
imgs.append(img3)
plt.imshow(img3)

# %% [markdown]
# #### LANCZOS4, 8x8

# %%
img4 = cv2.resize(img, dsize=(new_height, new_width), 
      interpolation=cv2.INTER_LANCZOS4)
imgs.append(img4)
plt.imshow(img4)

# %% [markdown]
# #### Area, ususally for shrinking

# %%
img5 = cv2.resize(img, dsize=(new_height, new_width), 
      interpolation=cv2.INTER_AREA)
imgs.append(img5)
plt.imshow(img5)

# %%
fig, axs = plt.subplots(ncols=2, nrows=3, figsize=(8, 10))
for i, ax in enumerate(axs.ravel()):
    ax.imshow(imgs[i])

# %% [markdown]
# ## Type Conversion

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
hsl_img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)

# %%
plt.imshow(hsv_img)

# %%
plt.imshow(hsl_img)

# %%
plt.imshow(gray_img, cmap='gray')

# %%
cv2.imwrite('out_img.jpeg', img, [int(cv2.IMWRITE_JPEG_QUALITY), 95])
cv2.imwrite('out_img.png', img)
# Out:
# True

# %% [markdown]
# ## Extraction of color bands

# %%
blue, green, red = cv2.split(img)

# %%
plt.imshow(blue, cmap="Blues")

# %%
plt.imshow(red, cmap="Reds")

# %%
plt.imshow(green, cmap="Greens")

# %%
image = cv2.imread("Butterfly.jpg")

# Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Reshape the image to a 2D array of pixels
pixels = image_rgb.reshape((-1, 3))

# Perform k-means clustering
num_clusters = 4 # You can adjust this value based on your requirement
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(pixels)

# Get the cluster centers and labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# Assign each pixel to its corresponding cluster center
segmented_image = centers[labels].reshape(image_rgb.shape)

# %%
# Display the original image and the segmented image
plt.figure(figsize=(10, 5))

plt.subplot(121)
plt.imshow(image_rgb)
plt.title('Original Image')

plt.subplot(122)
plt.imshow(segmented_image.astype(np.uint8))
plt.title('Segmented Image (K-Means Clustering)')

plt.show()

# Display the unique colors in a separate plot
plt.figure(figsize=(8, 2))
plt.imshow([centers.astype(np.uint8)])
plt.title('Unique Colors (Cluster Centers)')
plt.axis('off')
plt.show()

# %%
pixels.shape
# Out:
# (329130, 3)

# %%
image.shape
# Out:
# (477, 690, 3)

# %%
477*690
# Out:
# 329130
